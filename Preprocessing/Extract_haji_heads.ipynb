# %%
from skimage import io
from skimage import color
import numpy as np
from scipy.signal import convolve
import matplotlib.pyplot as plt
from scipy import ndimage
from skimage.filters import threshold_otsu, threshold_sauvola

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
hajis = io.imread('Hajj-umberllas.jpg')
hajis_gray = color.rgb2gray(hajis)
thresh = threshold_otsu(hajis_gray)
hajis_bin = hajis_gray > thresh

plt.figure(figsize=(15,15))
# plt.subplot(131)
plt.imshow(hajis)
# plt.subplot(132)
# plt.imshow(hajis_gray,'gray')
# plt.subplot(133)
# plt.imshow(hajis_bin,'gray')
# plt.show()

# %%
plt.figure(figsize=(15,15))
plt.imshow(hajis_bin,'gray')

# %%
plt.show()
